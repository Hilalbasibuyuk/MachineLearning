# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("DecisionTreesClassificationDataSet.csv")
df
# Out:
#     Deneyim Yili SuanCalisiyor?  Eski Calistigi Firmalar Egitim Seviyesi  \
# 0             11              Y                        4              BS
# 1              0              N                        0             PhD
# 2              5              Y                        2              MS
# 3              3              N                        1              BS
# 4              0              N                        0              BS
# 5             14              Y                        7              BS
# 6              1              N                        0              BS
# 7              1              N                        1             PhD
# 8              4              Y                        1              BS
# 9              0              N                        0             PhD
# 10             0              N                        0              BS
# 11             2              N                        0              BS
# 12             8              N                        6              BS
# 13             3              Y                        1              MS
# 14            19              N                        2             PhD
# 15             1              N                        0              BS
#
#    Top10 Universite? StajBizdeYaptimi? IseAlindi
# 0                  N                 N         Y
# 1                  Y                 Y         Y
# 2                  N                 Y         Y
# 3                  N                 Y         Y
# 4                  N                 N         N
# 5                  N                 N         Y
# 6                  N                 N         N
# 7                  Y                 N         N
# 8                  N                 Y         Y
# 9                  Y                 N         Y
# 10                 Y                 Y         Y
# 11                 Y                 Y         Y
# 12                 N                 N         N
# 13                 Y                 N         Y
# 14                 Y                 N         N
# 15                 N                 N         N

# %%
duzeltme_mapping = {"Y": 1, "N": 0}
df["SuanCalisiyor?"] = df["SuanCalisiyor?"].map(duzeltme_mapping)
df["Top10 Universite?"] = df["Top10 Universite?"].map(duzeltme_mapping)
df["IseAlindi"] = df["IseAlindi"].map(duzeltme_mapping)
df["StajBizdeYaptimi?"] = df["StajBizdeYaptimi?"].map(duzeltme_mapping)
df
# Out:
#     Deneyim Yili  SuanCalisiyor?  Eski Calistigi Firmalar Egitim Seviyesi  \
# 0             11               1                        4              BS
# 1              0               0                        0             PhD
# 2              5               1                        2              MS
# 3              3               0                        1              BS
# 4              0               0                        0              BS
# 5             14               1                        7              BS
# 6              1               0                        0              BS
# 7              1               0                        1             PhD
# 8              4               1                        1              BS
# 9              0               0                        0             PhD
# 10             0               0                        0              BS
# 11             2               0                        0              BS
# 12             8               0                        6              BS
# 13             3               1                        1              MS
# 14            19               0                        2             PhD
# 15             1               0                        0              BS
#
#     Top10 Universite?  StajBizdeYaptimi?  IseAlindi
# 0                   0                  0          1
# 1                   1                  1          1
# 2                   0                  1          1
# 3                   0                  1          1
# 4                   0                  0          0
# 5                   0                  0          1
# 6                   0                  0          0
# 7                   1                  0          0
# 8                   0                  1          1
# 9                   1                  0          1
# 10                  1                  1          1
# 11                  1                  1          1
# 12                  0                  0          0
# 13                  1                  0          1
# 14                  1                  0          0
# 15                  0                  0          0

# %%
duzeltme_mapping_egitim = {"BS":0, "PhD": 1, "MS": 2}
df["Egitim Seviyesi"] = df["Egitim Seviyesi"].map(duzeltme_mapping_egitim)
df
# Out:
#     Deneyim Yili  SuanCalisiyor?  Eski Calistigi Firmalar  Egitim Seviyesi  \
# 0             11               1                        4                0
# 1              0               0                        0                1
# 2              5               1                        2                2
# 3              3               0                        1                0
# 4              0               0                        0                0
# 5             14               1                        7                0
# 6              1               0                        0                0
# 7              1               0                        1                1
# 8              4               1                        1                0
# 9              0               0                        0                1
# 10             0               0                        0                0
# 11             2               0                        0                0
# 12             8               0                        6                0
# 13             3               1                        1                2
# 14            19               0                        2                1
# 15             1               0                        0                0
#
#     Top10 Universite?  StajBizdeYaptimi?  IseAlindi
# 0                   0                  0          1
# 1                   1                  1          1
# 2                   0                  1          1
# 3                   0                  1          1
# 4                   0                  0          0
# 5                   0                  0          1
# 6                   0                  0          0
# 7                   1                  0          0
# 8                   0                  1          1
# 9                   1                  0          1
# 10                  1                  1          1
# 11                  1                  1          1
# 12                  0                  0          0
# 13                  1                  0          1
# 14                  1                  0          0
# 15                  0                  0          0

# %%
y = df["IseAlindi"]
x = df.drop(["IseAlindi"],axis = 1)
x
# Out:
#     Deneyim Yili  SuanCalisiyor?  Eski Calistigi Firmalar  Egitim Seviyesi  \
# 0             11               1                        4                0
# 1              0               0                        0                1
# 2              5               1                        2                2
# 3              3               0                        1                0
# 4              0               0                        0                0
# 5             14               1                        7                0
# 6              1               0                        0                0
# 7              1               0                        1                1
# 8              4               1                        1                0
# 9              0               0                        0                1
# 10             0               0                        0                0
# 11             2               0                        0                0
# 12             8               0                        6                0
# 13             3               1                        1                2
# 14            19               0                        2                1
# 15             1               0                        0                0
#
#     Top10 Universite?  StajBizdeYaptimi?
# 0                   0                  0
# 1                   1                  1
# 2                   0                  1
# 3                   0                  1
# 4                   0                  0
# 5                   0                  0
# 6                   0                  0
# 7                   1                  0
# 8                   0                  1
# 9                   1                  0
# 10                  1                  1
# 11                  1                  1
# 12                  0                  0
# 13                  1                  0
# 14                  1                  0
# 15                  0                  0

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators = 200, random_state = 10)
rfc.fit(x,y)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=10)

# %%
print(rfc.predict([[5,1,3,0,0,0]]))
# Out:
# [1]
# C:\Users\hilal\anaconda3\envs\Hilal\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
print(rfc.predict([[2,0,7,0,1,0]]))
# Out:
# [0]
# C:\Users\hilal\anaconda3\envs\Hilal\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
